# %%
#Import dependencies
import pandas as pd
import numpy as np
from config import weather_api_key
from citipy import citipy
import requests
import time

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(low=-90.00, high=90.00, size=2000)
lngs=np.random.uniform(low=-180.00,high=180.00, size=2000)
lat_lngs=zip(lats,lngs)
# Add the latitudes and longitudes to a list.
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
    
len(cities)
# Out:
# 723

# %%
#Build the basic URL for the OpenWeatherMap
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data=[]

print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters
record_count=1
set_count=1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]['description']

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zlobin
# Processing Record 2 of Set 1 | yaqui
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | kavaratti
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | venice
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | narsaq
# Processing Record 13 of Set 1 | bac lieu
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | alofi
# Processing Record 16 of Set 1 | santana do livramento
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | matara
# Processing Record 19 of Set 1 | mendi
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | poum
# Processing Record 24 of Set 1 | pisco
# Processing Record 25 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | saldanha
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | pathein
# Processing Record 30 of Set 1 | lohardaga
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | egvekinot
# Processing Record 34 of Set 1 | nosy varika
# Processing Record 35 of Set 1 | visnes
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | mbanza-ngungu
# Processing Record 38 of Set 1 | wollongong
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | saint-georges
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | sitka
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | lerwick
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | hofn
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | ahuimanu
# Processing Record 1 of Set 2 | quatre cocos
# Processing Record 2 of Set 2 | bambanglipuro
# Processing Record 3 of Set 2 | faanui
# Processing Record 4 of Set 2 | jutai
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | aklavik
# Processing Record 8 of Set 2 | itaituba
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | sao jose da coroa grande
# Processing Record 12 of Set 2 | pangnirtung
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | fonte boa
# Processing Record 15 of Set 2 | batemans bay
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | chara
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | constitucion
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | brandon
# Processing Record 22 of Set 2 | tefe
# Processing Record 23 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 2 | aripuana
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 2 | jumla
# Processing Record 28 of Set 2 | humberto de campos
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | umba
# Processing Record 31 of Set 2 | saskylakh
# Processing Record 32 of Set 2 | husavik
# Processing Record 33 of Set 2 | labuhan
# Processing Record 34 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 2 | tutla
# City not found. Skipping...
# Processing Record 36 of Set 2 | chengde
# Processing Record 37 of Set 2 | boulsa
# Processing Record 38 of Set 2 | bambous virieux
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | monywa
# Processing Record 41 of Set 2 | kawalu
# Processing Record 42 of Set 2 | leningradskiy
# Processing Record 43 of Set 2 | huarmey
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 2 | koronowo
# Processing Record 47 of Set 2 | poro
# Processing Record 48 of Set 2 | fortuna
# Processing Record 49 of Set 2 | nara
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | yar-sale
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | oum hadjer
# Processing Record 4 of Set 3 | deqing
# Processing Record 5 of Set 3 | marabba
# Processing Record 6 of Set 3 | saint-philippe
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | thompson
# Processing Record 9 of Set 3 | manta
# Processing Record 10 of Set 3 | coihaique
# Processing Record 11 of Set 3 | gizo
# Processing Record 12 of Set 3 | kapaa
# Processing Record 13 of Set 3 | kashi
# Processing Record 14 of Set 3 | katsuura
# Processing Record 15 of Set 3 | port hedland
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | havre-saint-pierre
# Processing Record 20 of Set 3 | miyako
# Processing Record 21 of Set 3 | ancud
# Processing Record 22 of Set 3 | alice springs
# Processing Record 23 of Set 3 | hambantota
# Processing Record 24 of Set 3 | aykhal
# Processing Record 25 of Set 3 | half moon bay
# Processing Record 26 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 3 | akureyri
# Processing Record 28 of Set 3 | langham
# Processing Record 29 of Set 3 | cayenne
# Processing Record 30 of Set 3 | borogontsy
# Processing Record 31 of Set 3 | inhambane
# Processing Record 32 of Set 3 | mineros
# Processing Record 33 of Set 3 | castro
# Processing Record 34 of Set 3 | lasa
# Processing Record 35 of Set 3 | fomboni
# Processing Record 36 of Set 3 | ketchikan
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 3 | tasiilaq
# Processing Record 40 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 3 | airai
# Processing Record 42 of Set 3 | nigran
# Processing Record 43 of Set 3 | kualakapuas
# Processing Record 44 of Set 3 | manaure
# Processing Record 45 of Set 3 | kupino
# Processing Record 46 of Set 3 | lima
# Processing Record 47 of Set 3 | bengkulu
# Processing Record 48 of Set 3 | capitao poco
# Processing Record 49 of Set 3 | road town
# Processing Record 50 of Set 3 | bluff
# Processing Record 1 of Set 4 | umm lajj
# Processing Record 2 of Set 4 | banda aceh
# Processing Record 3 of Set 4 | verkhnyaya pyshma
# Processing Record 4 of Set 4 | port macquarie
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 4 | naryshkino
# Processing Record 8 of Set 4 | lata
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | vila velha
# Processing Record 11 of Set 4 | tiznit
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | kenai
# Processing Record 14 of Set 4 | meadow lake
# Processing Record 15 of Set 4 | tomatlan
# Processing Record 16 of Set 4 | santa maria
# Processing Record 17 of Set 4 | terrace
# Processing Record 18 of Set 4 | morada nova
# Processing Record 19 of Set 4 | catamarca
# Processing Record 20 of Set 4 | teya
# Processing Record 21 of Set 4 | los llanos de aridane
# Processing Record 22 of Set 4 | aldan
# Processing Record 23 of Set 4 | burnie
# Processing Record 24 of Set 4 | dawson creek
# Processing Record 25 of Set 4 | kendari
# Processing Record 26 of Set 4 | mahebourg
# Processing Record 27 of Set 4 | portland
# Processing Record 28 of Set 4 | geraldton
# Processing Record 29 of Set 4 | bilma
# Processing Record 30 of Set 4 | beloha
# Processing Record 31 of Set 4 | nyurba
# Processing Record 32 of Set 4 | flinders
# Processing Record 33 of Set 4 | vao
# Processing Record 34 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 4 | prieska
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | grenfell
# Processing Record 38 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 4 | barcelos
# Processing Record 40 of Set 4 | isla mujeres
# Processing Record 41 of Set 4 | umuahia
# Processing Record 42 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 4 | victoria
# Processing Record 44 of Set 4 | nantucket
# Processing Record 45 of Set 4 | kolosovka
# Processing Record 46 of Set 4 | acapulco
# Processing Record 47 of Set 4 | clyde river
# Processing Record 48 of Set 4 | grafenau
# Processing Record 49 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 4 | ahipara
# Processing Record 1 of Set 5 | lagoa
# Processing Record 2 of Set 5 | san cristobal
# Processing Record 3 of Set 5 | mackenzie
# Processing Record 4 of Set 5 | mayumba
# Processing Record 5 of Set 5 | carnarvon
# Processing Record 6 of Set 5 | slonim
# Processing Record 7 of Set 5 | mahibadhoo
# Processing Record 8 of Set 5 | laguna
# Processing Record 9 of Set 5 | san lorenzo de el escorial
# Processing Record 10 of Set 5 | presidencia roque saenz pena
# Processing Record 11 of Set 5 | richards bay
# Processing Record 12 of Set 5 | sangin
# Processing Record 13 of Set 5 | nanortalik
# Processing Record 14 of Set 5 | gumdag
# Processing Record 15 of Set 5 | pacific grove
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | hirara
# Processing Record 18 of Set 5 | esperance
# Processing Record 19 of Set 5 | ous
# Processing Record 20 of Set 5 | fairbanks
# Processing Record 21 of Set 5 | sinnamary
# Processing Record 22 of Set 5 | paita
# Processing Record 23 of Set 5 | kununurra
# Processing Record 24 of Set 5 | doha
# Processing Record 25 of Set 5 | walvis bay
# Processing Record 26 of Set 5 | zhangye
# Processing Record 27 of Set 5 | severo-yeniseyskiy
# Processing Record 28 of Set 5 | sumbe
# Processing Record 29 of Set 5 | san antonio
# Processing Record 30 of Set 5 | tlalancaleca
# City not found. Skipping...
# Processing Record 31 of Set 5 | collie
# Processing Record 32 of Set 5 | khatanga
# Processing Record 33 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 5 | lavrentiya
# Processing Record 35 of Set 5 | kangaatsiaq
# Processing Record 36 of Set 5 | malinovoye ozero
# Processing Record 37 of Set 5 | beringovskiy
# Processing Record 38 of Set 5 | agua dulce
# Processing Record 39 of Set 5 | bredasdorp
# Processing Record 40 of Set 5 | talnakh
# Processing Record 41 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 5 | poronaysk
# Processing Record 43 of Set 5 | kantang
# Processing Record 44 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 5 | buin
# Processing Record 46 of Set 5 | benavente
# Processing Record 47 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 48 of Set 5 | melilla
# Processing Record 49 of Set 5 | gamba
# Processing Record 50 of Set 5 | axim
# Processing Record 1 of Set 6 | mmabatho
# Processing Record 2 of Set 6 | ponta delgada
# Processing Record 3 of Set 6 | numan
# Processing Record 4 of Set 6 | qasigiannguit
# Processing Record 5 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 6 | avarua
# Processing Record 7 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 8 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 6 | novoagansk
# Processing Record 10 of Set 6 | filingue
# Processing Record 11 of Set 6 | xining
# Processing Record 12 of Set 6 | nidda
# Processing Record 13 of Set 6 | necochea
# Processing Record 14 of Set 6 | butaritari
# Processing Record 15 of Set 6 | jamestown
# Processing Record 16 of Set 6 | wanning
# Processing Record 17 of Set 6 | sur
# Processing Record 18 of Set 6 | mega
# Processing Record 19 of Set 6 | odweyne
# Processing Record 20 of Set 6 | oudtshoorn
# Processing Record 21 of Set 6 | saint george
# Processing Record 22 of Set 6 | havelock
# Processing Record 23 of Set 6 | tsimlyansk
# Processing Record 24 of Set 6 | port augusta
# Processing Record 25 of Set 6 | port moresby
# Processing Record 26 of Set 6 | sobolevo
# Processing Record 27 of Set 6 | nyazepetrovsk
# Processing Record 28 of Set 6 | saravan
# Processing Record 29 of Set 6 | segezha
# Processing Record 30 of Set 6 | knysna
# Processing Record 31 of Set 6 | santa fe
# Processing Record 32 of Set 6 | taoudenni
# Processing Record 33 of Set 6 | codrington
# Processing Record 34 of Set 6 | port shepstone
# Processing Record 35 of Set 6 | taihe
# Processing Record 36 of Set 6 | conceicao da barra
# Processing Record 37 of Set 6 | bismarck
# Processing Record 38 of Set 6 | petrovsk-zabaykalskiy
# Processing Record 39 of Set 6 | kharp
# Processing Record 40 of Set 6 | nowy dwor mazowiecki
# Processing Record 41 of Set 6 | bajil
# Processing Record 42 of Set 6 | hajnowka
# Processing Record 43 of Set 6 | mar del plata
# Processing Record 44 of Set 6 | longyearbyen
# Processing Record 45 of Set 6 | rio verde de mato grosso
# Processing Record 46 of Set 6 | adrar
# Processing Record 47 of Set 6 | sile
# Processing Record 48 of Set 6 | hasaki
# Processing Record 49 of Set 6 | erdenet
# Processing Record 50 of Set 6 | vestmannaeyjar
# Processing Record 1 of Set 7 | kytmanovo
# Processing Record 2 of Set 7 | tiarei
# Processing Record 3 of Set 7 | henties bay
# Processing Record 4 of Set 7 | muros
# Processing Record 5 of Set 7 | port elizabeth
# Processing Record 6 of Set 7 | tibu
# Processing Record 7 of Set 7 | coquimbo
# Processing Record 8 of Set 7 | umm kaddadah
# Processing Record 9 of Set 7 | constantine
# Processing Record 10 of Set 7 | prince rupert
# Processing Record 11 of Set 7 | robertsport
# Processing Record 12 of Set 7 | port hardy
# Processing Record 13 of Set 7 | trairi
# Processing Record 14 of Set 7 | ixtapa
# Processing Record 15 of Set 7 | pevek
# Processing Record 16 of Set 7 | awjilah
# Processing Record 17 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 7 | viedma
# Processing Record 19 of Set 7 | mahon
# Processing Record 20 of Set 7 | tezu
# Processing Record 21 of Set 7 | zhigansk
# Processing Record 22 of Set 7 | eureka
# Processing Record 23 of Set 7 | bandarbeyla
# Processing Record 24 of Set 7 | allahganj
# Processing Record 25 of Set 7 | guerrero negro
# Processing Record 26 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 7 | muriwai beach
# Processing Record 28 of Set 7 | fukue
# Processing Record 29 of Set 7 | zhovtneve
# Processing Record 30 of Set 7 | luanda
# Processing Record 31 of Set 7 | velsk
# Processing Record 32 of Set 7 | whitehorse
# Processing Record 33 of Set 7 | fare
# Processing Record 34 of Set 7 | riyadh
# Processing Record 35 of Set 7 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 36 of Set 7 | neiafu
# Processing Record 37 of Set 7 | sorland
# Processing Record 38 of Set 7 | minas de barroteran
# Processing Record 39 of Set 7 | chiltepec
# Processing Record 40 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 7 | oinoussai
# City not found. Skipping...
# Processing Record 42 of Set 7 | fayaoue
# Processing Record 43 of Set 7 | skjervoy
# Processing Record 44 of Set 7 | tiksi
# Processing Record 45 of Set 7 | mount isa
# Processing Record 46 of Set 7 | hualmay
# Processing Record 47 of Set 7 | iqaluit
# Processing Record 48 of Set 7 | inirida
# Processing Record 49 of Set 7 | cananeia
# Processing Record 50 of Set 7 | shache
# Processing Record 1 of Set 8 | willowmore
# Processing Record 2 of Set 8 | bhainsa
# Processing Record 3 of Set 8 | ugoofaaru
# Processing Record 4 of Set 8 | qaanaaq
# Processing Record 5 of Set 8 | jinxiang
# Processing Record 6 of Set 8 | celestun
# Processing Record 7 of Set 8 | yarada
# Processing Record 8 of Set 8 | hokitika
# Processing Record 9 of Set 8 | acarau
# Processing Record 10 of Set 8 | mezen
# Processing Record 11 of Set 8 | klaksvik
# Processing Record 12 of Set 8 | yekaterinovka
# Processing Record 13 of Set 8 | tabou
# Processing Record 14 of Set 8 | vieira de leiria
# Processing Record 15 of Set 8 | salalah
# Processing Record 16 of Set 8 | chillicothe
# Processing Record 17 of Set 8 | deputatskiy
# Processing Record 18 of Set 8 | scarborough
# Processing Record 19 of Set 8 | gravdal
# Processing Record 20 of Set 8 | port blair
# Processing Record 21 of Set 8 | honiara
# Processing Record 22 of Set 8 | padang
# Processing Record 23 of Set 8 | iskitim
# Processing Record 24 of Set 8 | biggar
# Processing Record 25 of Set 8 | kankon
# Processing Record 26 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 27 of Set 8 | oranjestad
# Processing Record 28 of Set 8 | boueni
# Processing Record 29 of Set 8 | loiza
# Processing Record 30 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 31 of Set 8 | peleduy
# Processing Record 32 of Set 8 | okha
# Processing Record 33 of Set 8 | morant bay
# Processing Record 34 of Set 8 | siparia
# Processing Record 35 of Set 8 | nago
# Processing Record 36 of Set 8 | san patricio
# Processing Record 37 of Set 8 | idlib
# Processing Record 38 of Set 8 | zelenoborsk
# Processing Record 39 of Set 8 | tarumovka
# Processing Record 40 of Set 8 | nemuro
# Processing Record 41 of Set 8 | muhos
# Processing Record 42 of Set 8 | nizwa
# Processing Record 43 of Set 8 | neos pirgos
# City not found. Skipping...
# Processing Record 44 of Set 8 | batagay-alyta
# Processing Record 45 of Set 8 | port-cartier
# Processing Record 46 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 8 | lyubech
# Processing Record 48 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 49 of Set 8 | vanavara
# Processing Record 50 of Set 8 | marsa matruh
# Processing Record 1 of Set 9 | saint-augustin
# Processing Record 2 of Set 9 | high level
# Processing Record 3 of Set 9 | tumut
# Processing Record 4 of Set 9 | asau
# Processing Record 5 of Set 9 | chumikan
# Processing Record 6 of Set 9 | okhotsk
# Processing Record 7 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 9 | cuajinicuilapa
# Processing Record 9 of Set 9 | avera
# Processing Record 10 of Set 9 | ochakiv
# Processing Record 11 of Set 9 | gazojak
# Processing Record 12 of Set 9 | ellensburg
# Processing Record 13 of Set 9 | xinmin
# Processing Record 14 of Set 9 | lakes entrance
# Processing Record 15 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 9 | kavieng
# Processing Record 17 of Set 9 | ngunguru
# Processing Record 18 of Set 9 | coalinga
# Processing Record 19 of Set 9 | takoradi
# Processing Record 20 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 21 of Set 9 | quang ngai
# Processing Record 22 of Set 9 | lompoc
# Processing Record 23 of Set 9 | reconquista
# Processing Record 24 of Set 9 | teguise
# Processing Record 25 of Set 9 | santarem
# Processing Record 26 of Set 9 | westport
# Processing Record 27 of Set 9 | shintomi
# Processing Record 28 of Set 9 | caravelas
# Processing Record 29 of Set 9 | fallon
# Processing Record 30 of Set 9 | suslovo
# Processing Record 31 of Set 9 | kruisfontein
# Processing Record 32 of Set 9 | kieta
# Processing Record 33 of Set 9 | saint-marc
# Processing Record 34 of Set 9 | port keats
# Processing Record 35 of Set 9 | tabory
# Processing Record 36 of Set 9 | kloulklubed
# Processing Record 37 of Set 9 | manokwari
# Processing Record 38 of Set 9 | malangali
# Processing Record 39 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 9 | mahajanga
# Processing Record 41 of Set 9 | vardo
# Processing Record 42 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 9 | naze
# Processing Record 44 of Set 9 | manggar
# Processing Record 45 of Set 9 | rundu
# Processing Record 46 of Set 9 | shenjiamen
# Processing Record 47 of Set 9 | ngorongoro
# Processing Record 48 of Set 9 | chapais
# Processing Record 49 of Set 9 | mazagao
# Processing Record 50 of Set 9 | sungaipenuh
# Processing Record 1 of Set 10 | ikalamavony
# Processing Record 2 of Set 10 | santa cruz cabralia
# Processing Record 3 of Set 10 | oriximina
# Processing Record 4 of Set 10 | lorengau
# Processing Record 5 of Set 10 | huilong
# Processing Record 6 of Set 10 | montefiascone
# Processing Record 7 of Set 10 | kupang
# Processing Record 8 of Set 10 | angoche
# Processing Record 9 of Set 10 | honningsvag
# Processing Record 10 of Set 10 | seoul
# Processing Record 11 of Set 10 | ust-maya
# Processing Record 12 of Set 10 | gravelbourg
# Processing Record 13 of Set 10 | suchedniow
# Processing Record 14 of Set 10 | tigil
# Processing Record 15 of Set 10 | altay
# Processing Record 16 of Set 10 | bellmawr
# Processing Record 17 of Set 10 | ankang
# Processing Record 18 of Set 10 | pokhara
# Processing Record 19 of Set 10 | college
# Processing Record 20 of Set 10 | yangcun
# Processing Record 21 of Set 10 | rosenberg
# Processing Record 22 of Set 10 | makali
# Processing Record 23 of Set 10 | kahului
# Processing Record 24 of Set 10 | verkhoyansk
# Processing Record 25 of Set 10 | kaohsiung
# Processing Record 26 of Set 10 | grand gaube
# Processing Record 27 of Set 10 | aswan
# Processing Record 28 of Set 10 | fontem
# Processing Record 29 of Set 10 | sao lourenco do sul
# Processing Record 30 of Set 10 | brae
# Processing Record 31 of Set 10 | gao
# Processing Record 32 of Set 10 | dingle
# Processing Record 33 of Set 10 | saumur
# Processing Record 34 of Set 10 | pahrump
# Processing Record 35 of Set 10 | pandan
# Processing Record 36 of Set 10 | iranshahr
# Processing Record 37 of Set 10 | muisne
# Processing Record 38 of Set 10 | bulz
# Processing Record 39 of Set 10 | mehamn
# Processing Record 40 of Set 10 | melo
# Processing Record 41 of Set 10 | te anau
# Processing Record 42 of Set 10 | paamiut
# Processing Record 43 of Set 10 | la ronge
# Processing Record 44 of Set 10 | vavuniya
# Processing Record 45 of Set 10 | tautira
# Processing Record 46 of Set 10 | harper
# Processing Record 47 of Set 10 | namatanai
# Processing Record 48 of Set 10 | smithers
# Processing Record 49 of Set 10 | faya
# Processing Record 50 of Set 10 | skotterud
# Processing Record 1 of Set 11 | kastrakion
# Processing Record 2 of Set 11 | raga
# Processing Record 3 of Set 11 | chaadayevka
# Processing Record 4 of Set 11 | bikaner
# Processing Record 5 of Set 11 | stara vyzhivka
# Processing Record 6 of Set 11 | sao felix do xingu
# Processing Record 7 of Set 11 | christchurch
# Processing Record 8 of Set 11 | sao borja
# Processing Record 9 of Set 11 | lac du bonnet
# Processing Record 10 of Set 11 | tanggul
# Processing Record 11 of Set 11 | nouakchott
# Processing Record 12 of Set 11 | bolanos de calatrava
# Processing Record 13 of Set 11 | nabire
# Processing Record 14 of Set 11 | podor
# Processing Record 15 of Set 11 | meulaboh
# Processing Record 16 of Set 11 | gafanha da nazare
# Processing Record 17 of Set 11 | challapata
# Processing Record 18 of Set 11 | zhob
# Processing Record 19 of Set 11 | pontes e lacerda
# Processing Record 20 of Set 11 | megion
# Processing Record 21 of Set 11 | ballarat
# Processing Record 22 of Set 11 | granada
# Processing Record 23 of Set 11 | vaitape
# Processing Record 24 of Set 11 | formosa
# Processing Record 25 of Set 11 | mayo
# Processing Record 26 of Set 11 | cabo san lucas
# Processing Record 27 of Set 11 | khromtau
# Processing Record 28 of Set 11 | azare
# Processing Record 29 of Set 11 | anori
# Processing Record 30 of Set 11 | senno
# Processing Record 31 of Set 11 | rosetown
# Processing Record 32 of Set 11 | osoyoos
# Processing Record 33 of Set 11 | jizan
# Processing Record 34 of Set 11 | berlevag
# Processing Record 35 of Set 11 | nacogdoches
# Processing Record 36 of Set 11 | xinqing
# Processing Record 37 of Set 11 | saint-louis
# Processing Record 38 of Set 11 | binika
# Processing Record 39 of Set 11 | sakakah
# Processing Record 40 of Set 11 | baykit
# Processing Record 41 of Set 11 | tokoroa
# Processing Record 42 of Set 11 | broome
# Processing Record 43 of Set 11 | kirovsk
# Processing Record 44 of Set 11 | dwarka
# Processing Record 45 of Set 11 | bathsheba
# Processing Record 46 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 11 | horizonte
# Processing Record 48 of Set 11 | savannah bight
# Processing Record 49 of Set 11 | isangel
# Processing Record 50 of Set 11 | hovd
# Processing Record 1 of Set 12 | twin falls
# Processing Record 2 of Set 12 | buala
# Processing Record 3 of Set 12 | makakilo city
# Processing Record 4 of Set 12 | cabedelo
# Processing Record 5 of Set 12 | kijang
# Processing Record 6 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 7 of Set 12 | maumere
# Processing Record 8 of Set 12 | neosho
# Processing Record 9 of Set 12 | goundam
# Processing Record 10 of Set 12 | rincon
# Processing Record 11 of Set 12 | riesa
# Processing Record 12 of Set 12 | domoni
# Processing Record 13 of Set 12 | grojec
# Processing Record 14 of Set 12 | tateyama
# Processing Record 15 of Set 12 | ongandjera
# Processing Record 16 of Set 12 | scheia
# Processing Record 17 of Set 12 | mikuni
# Processing Record 18 of Set 12 | manzil salim
# Processing Record 19 of Set 12 | arenapolis
# Processing Record 20 of Set 12 | strai
# Processing Record 21 of Set 12 | bairnsdale
# Processing Record 22 of Set 12 | xuanwu
# Processing Record 23 of Set 12 | ketchenery
# City not found. Skipping...
# Processing Record 24 of Set 12 | sar-e pul
# Processing Record 25 of Set 12 | damghan
# Processing Record 26 of Set 12 | oistins
# Processing Record 27 of Set 12 | westerland
# Processing Record 28 of Set 12 | brooks
# Processing Record 29 of Set 12 | linjiang
# Processing Record 30 of Set 12 | garissa
# Processing Record 31 of Set 12 | kondinskoye
# Processing Record 32 of Set 12 | sal rei
# Processing Record 33 of Set 12 | sehithwa
# Processing Record 34 of Set 12 | camargo
# Processing Record 35 of Set 12 | aksarka
# Processing Record 36 of Set 12 | san juan
# Processing Record 37 of Set 12 | itarema
# Processing Record 38 of Set 12 | seminole
# Processing Record 39 of Set 12 | belaya gora
# Processing Record 40 of Set 12 | sainte-rose
# Processing Record 41 of Set 12 | simbahan
# Processing Record 42 of Set 12 | katsina
# Processing Record 43 of Set 12 | moose factory
# Processing Record 44 of Set 12 | blahodatne
# Processing Record 45 of Set 12 | mareeba
# Processing Record 46 of Set 12 | dubbo
# Processing Record 47 of Set 12 | hamilton
# Processing Record 48 of Set 12 | sao joao da barra
# Processing Record 49 of Set 12 | margate
# Processing Record 50 of Set 12 | evensk
# Processing Record 1 of Set 13 | montepuez
# Processing Record 2 of Set 13 | karratha
# Processing Record 3 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 4 of Set 13 | prescott
# Processing Record 5 of Set 13 | mayaposi
# City not found. Skipping...
# Processing Record 6 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 13 | tabuk
# Processing Record 8 of Set 13 | havoysund
# Processing Record 9 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 10 of Set 13 | mersing
# Processing Record 11 of Set 13 | colares
# Processing Record 12 of Set 13 | touros
# Processing Record 13 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 14 of Set 13 | nortelandia
# Processing Record 15 of Set 13 | ravar
# Processing Record 16 of Set 13 | choucheng
# City not found. Skipping...
# Processing Record 17 of Set 13 | najran
# Processing Record 18 of Set 13 | vostok
# Processing Record 19 of Set 13 | san quintin
# Processing Record 20 of Set 13 | elk river
# Processing Record 21 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 13 | soyung
# Processing Record 24 of Set 13 | morrope
# Processing Record 25 of Set 13 | asosa
# Processing Record 26 of Set 13 | flores
# Processing Record 27 of Set 13 | mendahara
# City not found. Skipping...
# Processing Record 28 of Set 13 | porto novo
# Processing Record 29 of Set 13 | orcopampa
# Processing Record 30 of Set 13 | luena
# Processing Record 31 of Set 13 | mogadishu
# Processing Record 32 of Set 13 | mastic beach
# Processing Record 33 of Set 13 | mollendo
# Processing Record 34 of Set 13 | mwingi
# Processing Record 35 of Set 13 | comodoro rivadavia
# Processing Record 36 of Set 13 | biloela
# Processing Record 37 of Set 13 | chimbote
# Processing Record 38 of Set 13 | moron
# Processing Record 39 of Set 13 | mocuba
# Processing Record 40 of Set 13 | namibe
# Processing Record 41 of Set 13 | banov
# Processing Record 42 of Set 13 | waitati
# Processing Record 43 of Set 13 | san nicolas
# Processing Record 44 of Set 13 | kosonsoy
# Processing Record 45 of Set 13 | les cayes
# Processing Record 46 of Set 13 | amapa
# Processing Record 47 of Set 13 | shizunai
# Processing Record 48 of Set 13 | sorkjosen
# Processing Record 49 of Set 13 | luquillo
# Processing Record 50 of Set 13 | choma
# Processing Record 1 of Set 14 | springbok
# Processing Record 2 of Set 14 | ostrovnoy
# Processing Record 3 of Set 14 | jiuquan
# Processing Record 4 of Set 14 | korla
# Processing Record 5 of Set 14 | mamakan
# Processing Record 6 of Set 14 | jaora
# Processing Record 7 of Set 14 | kailua
# Processing Record 8 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 14 | shirgaon
# Processing Record 10 of Set 14 | borger
# Processing Record 11 of Set 14 | puerto escondido
# Processing Record 12 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 14 | tartus
# Processing Record 14 of Set 14 | sorong
# Processing Record 15 of Set 14 | ambon
# Processing Record 16 of Set 14 | pilar
# Processing Record 17 of Set 14 | vermillion
# Processing Record 18 of Set 14 | fort nelson
# Processing Record 19 of Set 14 | humaita
# Processing Record 20 of Set 14 | yumen
# Processing Record 21 of Set 14 | kidal
# Processing Record 22 of Set 14 | puerto cabezas
# Processing Record 23 of Set 14 | mount gambier
# Processing Record 24 of Set 14 | riberalta
# Processing Record 25 of Set 14 | porto walter
# Processing Record 26 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 27 of Set 14 | manzhouli
# Processing Record 28 of Set 14 | sept-iles
# Processing Record 29 of Set 14 | plettenberg bay
# Processing Record 30 of Set 14 | mugla
# Processing Record 31 of Set 14 | sola
# Processing Record 32 of Set 14 | nichlaul
# Processing Record 33 of Set 14 | broken hill
# Processing Record 34 of Set 14 | araouane
# Processing Record 35 of Set 14 | bagdarin
# Processing Record 36 of Set 14 | mwanza
# Processing Record 37 of Set 14 | ormara
# Processing Record 38 of Set 14 | sao filipe
# Processing Record 39 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 40 of Set 14 | cabra
# Processing Record 41 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 42 of Set 14 | artesia
# Processing Record 43 of Set 14 | tombouctou
# Processing Record 44 of Set 14 | petrovsk
# Processing Record 45 of Set 14 | campina verde
# Processing Record 46 of Set 14 | raudeberg
# Processing Record 47 of Set 14 | vila franca do campo
# Processing Record 48 of Set 14 | katangli
# Processing Record 49 of Set 14 | bogorodskoye
# Processing Record 50 of Set 14 | ampanihy
# Processing Record 1 of Set 15 | ippy
# Processing Record 2 of Set 15 | kenora
# Processing Record 3 of Set 15 | carutapera
# Processing Record 4 of Set 15 | narvik
# Processing Record 5 of Set 15 | rafsanjan
# Processing Record 6 of Set 15 | phan thiet
# Processing Record 7 of Set 15 | mgachi
# Processing Record 8 of Set 15 | morgan city
# Processing Record 9 of Set 15 | sunland park
# Processing Record 10 of Set 15 | suntar
# Processing Record 11 of Set 15 | anadyr
# Processing Record 12 of Set 15 | gat
# Processing Record 13 of Set 15 | pafos
# Processing Record 14 of Set 15 | verkh-usugli
# Processing Record 15 of Set 15 | samana
# Processing Record 16 of Set 15 | arman
# Processing Record 17 of Set 15 | peniche
# Processing Record 18 of Set 15 | rivera
# Processing Record 19 of Set 15 | oranjemund
# Processing Record 20 of Set 15 | cheremisinovo
# Processing Record 21 of Set 15 | seguin
# Processing Record 22 of Set 15 | komsomolskiy
# Processing Record 23 of Set 15 | zaraza
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Adding the data to a new DataFrame
weatherpy_df=pd.DataFrame(city_data)
weatherpy_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Zlobin      HR  45.2924   14.6541     43.38        84          75
# 1         Yaqui      MX  27.3667 -110.1667     58.91        59           0
# 2        Kodiak      US  57.7900 -152.4072     36.91        48         100
# 3  Ponta Do Sol      PT  32.6667  -17.1000     63.23        68           5
# 4     Busselton      AU -33.6500  115.3333     68.04        56          65
#
#    Wind Speed Current Description
# 0        5.75       broken clouds
# 1       11.52           clear sky
# 2        5.75     overcast clouds
# 3       10.47           clear sky
# 4       20.00       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
weatherpy_df.to_csv(output_data_file, index_label='City_ID')
